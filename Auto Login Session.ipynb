# %%
import requests
from bs4 import BeautifulSoup



header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'
}

login_data = {
    'email': 'zia.ahmad@ucp.edu.pk',
    'password': 'tobechanged'
}


url = 'https://www.codewars.com/users/sign_in'
s = requests.Session()
data = s.get(url, headers = header)
soup = BeautifulSoup(data.content, 'html5lib')
login_data['authenticity_token'] = soup.find('input', attrs={'name': 'authenticity_token'})['value']

login_data = s.post(url, data=login_data, headers=header)

# print(login_data.content)

print(s.get('https://www.codewars.com/users/ziaahmad457', headers=header).content)
# Out:
# b'<!DOCTYPE html><html class="dark"><head><meta charset="utf-8" />\n<script>window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"364dba19a3","applicationID":"15446117","transactionName":"Jg5ZQEdYXQ1XRRZAQQATRBtGX14W","queueTime":0,"applicationTime":50,"agent":""}</script>\n<script>(window.NREUM||(NREUM={})).loader_config={licenseKey:"364dba19a3",applicationID:"15446117"};window.NREUM||(NREUM={}),__nr_require=function(e,t,n){function r(n){if(!t[n]){var i=t[n]={exports:{}};e[n][0].call(i.exports,function(t){var i=e[n][1][t];return r(i||t)},i,i.exports)}return t[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(e,t,n){function r(){}function i(e,t,n){return function(){return o(e,[u.now()].concat(c(arguments)),t?null:this,n),t?void 0:this}}var o=e("handle"),a=e(6),c=e(7),f=e("ee").get("tracer"),u=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrel
# ...

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'
}

login_data = {
    'email': 'zia.ahmad@ucp.edu.pk',
    'password': 'tobechanged'
}


login_data['authenticity_token'] = soup.find('input', attrs={'name': 'authenticity_token'})['value']


print(s.get('https://www.codewars.com/users/ziaahmad457', headers=headers).content)
